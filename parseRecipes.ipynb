# %%
import numpy as np
import pandas as pd
from collections import defaultdict
import time
from tqdm import tqdm as ProgressBar
import six # needed for Google Cloud client
import sys
import pickle
import operator
import nltk
import zlib
import cPickle
import parsing_util
import cleaning_util

import en # NodeBox https://www.nodebox.net/code/index.php/Linguistics#verb_conjugation

from google.cloud import language
from google.cloud.language import enums
from google.cloud.language import types

# %%
df=pd.read_pickle('CleanedIngredients.pkl')
df2=df.set_index("url")
ingredientsDict=pd.read_pickle('unique_ingredients.pkl')

# %%
df["ingredients"].sample(5)
# Out:
# 1254     [2 tablespoons olive oil, 1/4 cup lemon juice,...
# 2451     [2 over-ripe bananas, broken into chunks, 1 1/...
# 1627     [2 tablespoons grated Parmesan cheese, 2 table...
# 12507    [1 mango - peeled, seeded, and chopped, 1/4 cu...
# 3801     [1 cup butter, softened, 3/4 cup white sugar, ...
# Name: ingredients, dtype: object

# %%
df.sample(1)
# Out:
#                                              categories cookingTime  \
# 3158  [Granola Bars, Snack Recipes, Appetizers and S...       PT15M
#
#      description                                        ingredients  \
# 3158         NaN  [1 cup raw hemp seeds, 6 Medjool dates, pitted...
#
#                                        instructionSteps  \
# 3158  [Grind hemp seeds into a powder in a food proc...
#
#                                 name  rating  ratingCount  \
# 3158  Healthy Chocolate Energy Balls     0.0            0
#
#                                                     url  cookingTimeMinutes  \
# 3158  http://allrecipes.com/recipe/245017/healthy-ch...                15.0
#
#                              cleanedIngredients
# 3158  [hemp seeds, medjool dates, cocoa powder]

# %%
# Iterate through df parse ingredients into a compressed dictionary, and save on disk.
client = language.LanguageServiceClient()
IngredientsDict=defaultdict()
IngredientsDict=pd.read_pickle('parsedIngredients.pkl')  
added=0
#df2=df.sample(1)
for idx, row in ProgressBar(df.iterrows(), desc="Processing ingredients"):
    if row["url"] in IngredientsDict: continue
    # print 'loading ' + row["url"]   
    ingredients = '.'.join(ingredient for ingredient in row['ingredients'])
    if isinstance(ingredients, six.binary_type):
        ingredients = ingredients.decode('utf-8')

    # Instantiates a plain text document.
    document = types.Document(
        content=ingredients,
        type=enums.Document.Type.PLAIN_TEXT)

        # Detects syntax in the document. You can also analyze HTML with:
        #   document.type == enums.Document.Type.HTML
    #tokens = client.analyze_syntax(document).tokens
    tokens = client.annotate_text(document, {'extract_syntax': True,}).tokens
    tokensList=list(tokens)
    IngredientsDict[row['url']]=zlib.compress(cPickle.dumps(tokensList))
    added += 1
    if added > 10000:
        with open('parsedIngredients.pkl', 'wb') as f:
            pickle.dump(IngredientsDict, f) 
        added = 0
    
with open('parsedIngredients.pkl', 'wb') as f:
    pickle.dump(IngredientsDict, f)
# Out:
# Processing ingredients: 104680it [00:08, 12637.00it/s]

# %%
#IngredientsDict=pd.read_pickle('parsedIngredients.pkl')  
print len(IngredientsDict)
#for key,value in ingredientsDict.iteritems():
#    print key
#with open('parsedIngredients.pkl', 'wb') as f:
#    pickle.dump(IngredientsDict, f)
# Out:
# 48417

# %%
# Iterate through df parse instructions into a compressed dictionary, and save on disk.
client = language.LanguageServiceClient()
InstructionsDict=defaultdict()
InstructionsDict=pd.read_pickle('parsedInstructions.pkl')  
added=0

for idx, row in ProgressBar(df.iterrows(), desc="Processing recipes"):
    if row["url"] in InstructionsDict: continue
    # print 'loading ' + row["url"]   
    instructions = '.'.join(instruction for instruction in row['instructionSteps'])
    if isinstance(instructions, six.binary_type):
        instructions = instructions.decode('utf-8')

    # Instantiates a plain text document.
    document = types.Document(
        content=instructions,
        type=enums.Document.Type.PLAIN_TEXT)

        # Detects syntax in the document. You can also analyze HTML with:
        #   document.type == enums.Document.Type.HTML
    #tokens = client.analyze_syntax(document).tokens
    tokens = client.annotate_text(document, {'extract_syntax': True,}).tokens
    tokensList=list(tokens)
    InstructionsDict[row['url']]=zlib.compress(cPickle.dumps(tokensList))
    added += 1
    if added > 10000:
        with open('parsedInstructions.pkl', 'wb') as f:
            pickle.dump(InstructionsDict, f) 
        added = 0
    
with open('parsedInstructions.pkl', 'wb') as f:
    pickle.dump(InstructionsDict, f)
    
#ingredientsDict=pd.read_pickle('parsedInstruction.pkl')    
#for key,value in ingredientsDict.iteritems():
#    print key
# Out:
# Processing recipes: 104680it [03:05, 563.55it/s]

# %%
CleanIngredientsDict=pd.read_pickle('parsedInstructions.pkl')  
print len(IngredientsDict)
#for key,value in ingredientsDict.iteritems():
#    print key
#with open('parsedIngredients.pkl', 'wb') as f:
#    pickle.dump(IngredientsDict, f)
# Out:
# 48417

# %%
df2.loc['http://allrecipes.com/recipe/18080/almond-macaroon-nests/']["instructionSteps"]
#df.drop_duplicates(subset='url', keep='first', inplace=True)
# Out:
# [u'Preheat oven to 325 degrees F (165 degrees C). Grease cookie sheets.',
#  u'Sift together the flour, baking powder and salt; set aside. In a medium bowl, cream together the butter, cream cheese, and sugar until smooth. Stir in the vanilla, then gradually beat in the dry ingredients.',
#  u"Divide the coconut into three separate containers (see Cook's Note). Color one portion red, one yellow, and leave one plain. Toss the colored coconut together with the plain.",
#  u'Roll cookie dough into walnut-sized balls, then roll the balls in the coconut mixture. Place them 2 inches apart onto the prepared cookie sheet. Press 1 candy into the center of each cookie.',
#  u'Bake for 12 minutes in the preheated oven, then remove from the oven and press 2 more candies into the center of each cookie. Return to the oven to continue baking for another 4 to 5 minutes, until golden brown. Cool cookies on the baking sheet for a few minutes before removing to a wire rack to cool completely.']

# %%
df.shape
# Out:
# (48417, 11)

# %%
insDict=parsing_util.Instructions()
url='http://allrecipes.com/recipe/18080/almond-macaroon-nests/'
instructions=df2.loc[url]["instructionSteps"]
parsedInstructions = insDict.parse(url, instructions)
print parsedInstructions
insDict.close()
# Out:
# [text {
#   content: "Preheat"
#   begin_offset: -1
# }
# part_of_speech {
#   tag: DET
# }
# dependency_edge {
#   head_token_index: 1
#   label: DET
# }
# lemma: "Preheat"
# , text {
#   content: "oven"
#   begin_offset: -1
# }
# part_of_speech {
#   tag: NOUN
#   number: SINGULAR
# }
# dependency_edge {
#   head_token_index: 1
#   label: ROOT
# }
# lemma: "oven"
# , text {
#   content: "to"
#   begin_offset: -1
# }
# part_of_speech {
#   tag: ADP
# }
# dependency_edge {
#   head_token_index: 1
#   label: PREP
# }
# lemma: "to"
# , text {
#   content: "325"
#   begin_offset: -1
# }
# part_of_speech {
#   tag: NUM
# }
# dependency_edge {
#   head_token_index: 5
#   label: NUM
# }
# lemma: "325"
# , text {
#   content: "degrees"
#   begin_offset: -1
# }
# part_of_speech {
#   tag: NOUN
#   number: PLURAL
# }
# dependency_edge {
#   head_token_index: 5
#   label: NN
# }
# lemma: "degree"
# , text {
#   content: "F"
#   begin_offset: -1
# }
# part_of_speech {
#   tag: NOUN
#   number: SINGULAR
# }
# dependency_edge {
#   head_token_index: 2
#   label: POBJ
# }
# lemma: "F"
# , text {
#   content: "("
#   begin_offset: -1
# }
# part_of_speech {
#   tag: PUNCT
# }
# dependency_edge {
#   head_token_index: 5
#   label: P
# }
# lemma: "("
# , text {
#   content: "165"
#   begin_offset: -1
# }
# part_of_speech {
#   tag: NUM
# }
# dependency_edge {
#   head_token_index: 8
#   label: NUM
# }
# lemma: "165"
# , text {
#   content: "degrees"
#   begin_offset: -1
# }
# part_of_speech {
#   tag: NOUN
#   number: PLURAL
# }
# dependency_edge {
#   head_token_index: 9
#   label: NN
# }
# lemma: "degree"
# , text {
#   content: "C"
#   begin_offset: -1
# }
# part_of_speech {
#   tag: NOUN
#   number: SINGULAR
# }
# dependency_edge {
#   head_token_index: 5
#   label: APPOS
# }
# lemma: "C"
# , text {
#   content: ")"
#   begin_offset: -1
# }
# part_of_speech {
#   tag: PUNCT
# }
# dependency_edge {
#   head_token_index: 5
#   label: P
# }
# lemma: ")"
# , text {
#   content: "."
#   begin_offset: -1
# }
# part_of_speech {
#   tag: PUNCT
# }
# dependency_edge {
#   head_token_index: 1
#   label: P
# }
# lemma: "."
# , text {
#   content: "Grease"
#   begin_offset: -1
# }
# part_of_speech {
#   tag: NOUN
#   number: SINGULAR
# }
# dependency_edge {
#   head_token_index: 14
#   label: NN
# }
# lemma: "Grease"
# , text {
#   content: "cookie"
#   begin_offset: -1
# }
# part_of_speech {
#   tag: NOUN
#   number: SINGULAR
# }
# dependency_edge {
#   head_token_index: 14
#   label: NN
# }
# lemma: "cookie"
# , text {
#   content: "sheets"
#   begin_offset: -1
# }
# part_of_speech {
#   tag: NOUN
#   number: SINGULAR
# }
# dependency_edge {
#   head_token_index: 16
#   label: NSUBJ
# }
# lemma: "sheet"
# , text {
#   content: ".."
#   begin_offset: -1
# }
# part_of_speech {
#   tag: PUNCT
# }
# dependency_edge {
#   head_token_index: 16
#   label: P
# }
# lemma: ".."
# , text {
#   content: "Sift"
#   begin_offset: -1
# }
# part_of_speech {
#   tag: VERB
# }
# dependency_edge {
#   head_token_index: 16
#   label: ROOT
# }
# lemma: "Sift"
# , text {
#   content: "together"
#   begin_offset: -1
# }
# part_of_speech {
#   tag: ADV
# }
# dependency_edge {
#   head_token_index: 16
#   label: ADVMOD
# }
# lemma: "together"
# , text {
#   content: "the"
#   begin_offset: -1
# }
# part_of_speech {
#   tag: DET
# }
# dependency_edge {
#   head_token_index: 19
#   label: DET
# }
# lemma: "the"
# , text {
#   content: "flour"
#   begin_offset: -1
# }
# part_of_speech {
#   tag: NOUN
#   number: SINGULAR
# }
# dependency_edge {
#   head_token_index: 16
#   label: DOBJ
# }
# lemma: "flour"
# , text {
#   content: ","
#   begin_offset: -1
# }
# part_of_speech {
#   tag: PUNCT
# }
# dependency_edge {
#   head_token_index: 19
#   label: P
# }
# lemma: ","
# , text {
#   content: "baking"
#   begin_offset: -1
# }
# part_of_speech {
#   tag: NOUN
#   number: SINGULAR
# }
# dependency_edge {
#   head_token_index: 22
#   label: NN
# }
# lemma: "baking"
# , text {
#   content: "powder"
#   begin_offset: -1
# }
# part_of_speech {
#   tag: NOUN
#   number: SINGULAR
# }
# dependency_edge {
#   head_token_index: 19
#   label: CONJ
# }
# lemma: "powder"
# , text {
#   content: "and"
#   begin_offset: -1
# }
# part_of_speech {
#   tag: CONJ
# }
# dependency_edge {
#   head_token_index: 19
#   label: CC
# }
# lemma: "and"
# , text {
#   content: "salt"
#   begin_offset: -1
# }
# part_of_speech {
#   tag: NOUN
#   number: SINGULAR
# }
# dependency_edge {
#   head_token_index: 19
#   label: CONJ
# }
# lemma: "salt"
# , text {
#   content: ";"
#   begin_offset: -1
# }
# part_of_speech {
#   tag: PUNCT
# }
# dependency_edge {
#   head_token_index: 16
#   label: P
# }
# lemma: ";"
# , text {
#   content: "set"
#   begin_offset: -1
# }
# part_of_speech {
#   tag: VERB
# }
# dependency_edge {
#   head_token_index: 16
#   label: PARATAXIS
# }
# lemma: "set"
# , text {
#   content: "aside"
#   begin_offset: -1
# }
# part_of_speech {
#   tag: ADV
# }
# dependency_edge {
#   head_token_index: 26
#   label: ADVMOD
# }
# lemma: "aside"
# , text {
#   content: "."
#   begin_offset: -1
# }
# part_of_speech {
#   tag: PUNCT
# }
# dependency_edge {
#   head_token_index: 16
#   label: P
# }
# lemma: "."
# , text {
#   content: "In"
#   begin_offset: -1
# }
# part_of_speech {
#   tag: ADP
# }
# dependency_edge {
#   head_token_index: 34
#   label: PREP
# }
# lemma: "In"
# , text {
#   content: "a"
#   begin_offset: -1
# }
# part_of_speech {
#   tag: DET
# }
# dependency_edge {
#   head_token_index: 32
#   label: DET
# }
# lemma: "a"
# , text {
#   content: "medium"
#   begin_offset: -1
# }
# part_of_speech {
#   tag: ADJ
#   number: SINGULAR
# }
# dependency_edge {
#   head_token_index: 32
#   label: AMOD
# }
# lemma: "medium"
# , text {
#   content: "bowl"
#   begin_offset: -1
# }
# part_of_speech {
#   tag: NOUN
#   number: SINGULAR
# }
# dependency_edge {
#   head_token_index: 29
#   label: POBJ
# }
# lemma: "bowl"
# , text {
#   content: ","
#   begin_offset: -1
# }
# part_of_speech {
#   tag: PUNCT
# }
# dependency_edge {
#   head_token_index: 34
#   label: P
# }
# lemma: ","
# , text {
#   content: "cream"
#   begin_offset: -1
# }
# part_of_speech {
#   tag: NOUN
#   number: SINGULAR
# }
# dependency_edge {
#   head_token_index: 34
#   label: ROOT
# }
# lemma: "cream"
# , text {
#   content: "together"
#   begin_offset: -1
# }
# part_of_speech {
#   tag: ADV
# }
# dependency_edge {
#   head_token_index: 34
#   label: ADVMOD
# }
# lemma: "together"
# , text {
#   content: "the"
#   begin_offset: -1
# }
# part_of_speech {
#   tag: DET
# }
# dependency_edge {
#   head_token_index: 37
#   label: DET
# }
# lemma: "the"
# , text {
#   content: "butter"
#   begin_offset: -1
# }
# part_of_speech {
#   tag: NOUN
#   number: SINGULAR
# }
# dependency_edge {
#   head_token_index: 34
#   label: DOBJ
# }
# lemma: "butter"
# , text {
#   content: ","
#   begin_offset: -1
# }
# part_of_speech {
#   tag: PUNCT
# }
# dependency_edge {
#   head_token_index: 37
#   label: P
# }
# lemma: ","
# , text {
#   content: "cream"
#   begin_offset: -1
# }
# part_of_speech {
#   tag: NOUN
#   number: SINGULAR
# }
# dependency_edge {
#   head_token_index: 40
#   label: NN
# }
# lemma: "cream"
# , text {
#   content: "cheese"
#   begin_offset: -1
# }
# part_of_speech {
#   tag: NOUN
#   number: SINGULAR
# }
# dependency_edge {
#   head_token_index: 37
#   label: CONJ
# }
# lemma: "cheese"
# , text {
#   content: ","
#   begin_offset: -1
# }
# part_of_speech {
#   tag: PUNCT
# }
# dependency_edge {
#   head_token_index: 37
#   label: P
# }
# lemma: ","
# , text {
#   content: "and"
#   begin_offset: -1
# }
# part_of_speech {
#   tag: CONJ
# }
# dependency_edge {
#   head_token_index: 37
#   label: CC
# }
# lemma: "and"
# , text {
#   content: "sugar"
#   begin_offset: -1
# }
# part_of_speech {
#   tag: NOUN
#   number: SINGULAR
# }
# dependency_edge {
#   head_token_index: 37
#   label: CONJ
# }
# lemma: "sugar"
# , text {
#   content: "until"
#   begin_offset: -1
# }
# part_of_speech {
#   tag: ADP
# }
# dependency_edge {
#   head_token_index: 34
#   label: PREP
# }
# lemma: "until"
# , text {
#   content: "smooth"
#   begin_offset: -1
# }
# part_of_speech {
#   tag: ADJ
# }
# dependency_edge {
#   head_token_index: 44
#   label: POBJ
# }
# lemma: "smooth"
# , text {
#   content: "."
#   begin_offset: -1
# }
# part_of_speech {
#   tag: PUNCT
# }
# dependency_edge {
#   head_token_index: 34
#   label: P
# }
# lemma: "."
# , text {
#   content: "Stir"
#   begin_offset: -1
# }
# part_of_speech {
#   tag: NOUN
#   number: SINGULAR
# }
# dependency_edge {
#   head_token_index: 47
#   label: ROOT
# }
# lemma: "Stir"
# , text {
#   content: "in"
#   begin_offset: -1
# }
# part_of_speech {
#   tag: ADP
# }
# dependency_edge {
#   head_token_index: 47
#   label: PREP
# }
# lemma: "in"
# , text {
#   content: "the"
#   begin_offset: -1
# }
# part_of_speech {
#   tag: DET
# }
# dependency_edge {
#   head_token_index: 50
#   label: DET
# }
# lemma: "the"
# , text {
#   content: "vanilla"
#   begin_offset: -1
# }
# part_of_speech {
#   tag: NOUN
#   number: SINGULAR
# }
# dependency_edge {
#   head_token_index: 48
#   label: POBJ
# }
# lemma: "vanilla"
# , text {
#   content: ","
#   begin_offset: -1
# }
# part_of_speech {
#   tag: PUNCT
# }
# dependency_edge {
#   head_token_index: 47
#   label: P
# }
# lemma: ","
# , text {
#   content: "then"
#   begin_offset: -1
# }
# part_of_speech {
#   tag: ADV
# }
# dependency_edge {
#   head_token_index: 47
#   label: ADVMOD
# }
# lemma: "then"
# , text {
#   content: "gradually"
#   begin_offset: -1
# }
# part_of_speech {
#   tag: ADV
# }
# dependency_edge {
#   head_token_index: 54
#   label: ADVMOD
# }
# lemma: "gradually"
# , text {
#   content: "beat"
#   begin_offset: -1
# }
# part_of_speech {
#   tag: VERB
#   mood: INDICATIVE
#   tense: PRESENT
# }
# dependency_edge {
#   head_token_index: 47
#   label: DEP
# }
# lemma: "beat"
# , text {
#   content: "in"
#   begin_offset: -1
# }
# part_of_speech {
#   tag: ADP
# }
# dependency_edge {
#   head_token_index: 54
#   label: PREP
# }
# lemma: "in"
# , text {
#   content: "the"
#   begin_offset: -1
# }
# part_of_speech {
#   tag: DET
# }
# dependency_edge {
#   head_token_index: 58
#   label: DET
# }
# lemma: "the"
# , text {
#   content: "dry"
#   begin_offset: -1
# }
# part_of_speech {
#   tag: ADJ
# }
# dependency_edge {
#   head_token_index: 58
#   label: AMOD
# }
# lemma: "dry"
# , text {
#   content: "ingredients"
#   begin_offset: -1
# }
# part_of_speech {
#   tag: NOUN
#   number: PLURAL
# }
# dependency_edge {
#   head_token_index: 55
#   label: POBJ
# }
# lemma: "ingredient"
# , text {
#   content: ".."
#   begin_offset: -1
# }
# part_of_speech {
#   tag: PUNCT
# }
# dependency_edge {
#   head_token_index: 47
#   label: P
# }
# lemma: ".."
# , text {
#   content: "Divide"
#   begin_offset: -1
# }
# part_of_speech {
#   tag: VERB
# }
# dependency_edge {
#   head_token_index: 47
#   label: DEP
# }
# lemma: "Divide"
# , text {
#   content: "the"
#   begin_offset: -1
# }
# part_of_speech {
#   tag: DET
# }
# dependency_edge {
#   head_token_index: 62
#   label: DET
# }
# lemma: "the"
# , text {
#   content: "coconut"
#   begin_offset: -1
# }
# part_of_speech {
#   tag: NOUN
#   number: SINGULAR
# }
# dependency_edge {
#   head_token_index: 60
#   label: DOBJ
# }
# lemma: "coconut"
# , text {
#   content: "into"
#   begin_offset: -1
# }
# part_of_speech {
#   tag: ADP
# }
# dependency_edge {
#   head_token_index: 60
#   label: PREP
# }
# lemma: "into"
# , text {
#   content: "three"
#   begin_offset: -1
# }
# part_of_speech {
#   tag: NUM
# }
# dependency_edge {
#   head_token_index: 66
#   label: NUM
# }
# lemma: "three"
# , text {
#   content: "separate"
#   begin_offset: -1
# }
# part_of_speech {
#   tag: ADJ
# }
# dependency_edge {
#   head_token_index: 66
#   label: AMOD
# }
# lemma: "separate"
# , text {
#   content: "containers"
#   begin_offset: -1
# }
# part_of_speech {
#   tag: NOUN
#   number: PLURAL
# }
# dependency_edge {
#   head_token_index: 63
#   label: POBJ
# }
# lemma: "container"
# , text {
#   content: "("
#   begin_offset: -1
# }
# part_of_speech {
#   tag: PUNCT
# }
# dependency_edge {
#   head_token_index: 68
#   label: P
# }
# lemma: "("
# , text {
#   content: "see"
#   begin_offset: -1
# }
# part_of_speech {
#   tag: VERB
#   mood: IMPERATIVE
# }
# dependency_edge {
#   head_token_index: 60
#   label: PARATAXIS
# }
# lemma: "see"
# , text {
#   content: "Cook"
#   begin_offset: -1
# }
# part_of_speech {
#   tag: NOUN
#   number: SINGULAR
#   proper: PROPER
# }
# dependency_edge {
#   head_token_index: 71
#   label: POSS
# }
# lemma: "Cook"
# , text {
#   content: "\'s"
#   begin_offset: -1
# }
# part_of_speech {
#   tag: PRT
# }
# dependency_edge {
#   head_token_index: 69
#   label: PS
# }
# lemma: "\'s"
# , text {
#   content: "Note"
#   begin_offset: -1
# }
# part_of_speech {
#   tag: NOUN
#   number: SINGULAR
# }
# dependency_edge {
#   head_token_index: 68
#   label: DOBJ
# }
# lemma: "Note"
# , text {
#   content: ")"
#   begin_offset: -1
# }
# part_of_speech {
#   tag: PUNCT
# }
# dependency_edge {
#   head_token_index: 68
#   label: P
# }
# lemma: ")"
# , text {
#   content: "."
#   begin_offset: -1
# }
# part_of_speech {
#   tag: PUNCT
# }
# dependency_edge {
#   head_token_index: 47
#   label: P
# }
# lemma: "."
# , text {
#   content: "Color"
#   begin_offset: -1
# }
# part_of_speech {
#   tag: NOUN
#   number: SINGULAR
# }
# dependency_edge {
#   head_token_index: 77
#   label: NN
# }
# lemma: "Color"
# , text {
#   content: "one"
#   begin_offset: -1
# }
# part_of_speech {
#   tag: NUM
# }
# dependency_edge {
#   head_token_index: 76
#   label: NUM
# }
# lemma: "one"
# , text {
#   content: "portion"
#   begin_offset: -1
# }
# part_of_speech {
#   tag: NOUN
#   number: SINGULAR
# }
# dependency_edge {
#   head_token_index: 77
#   label: NN
# }
# lemma: "portion"
# , text {
#   content: "red"
#   begin_offset: -1
# }
# part_of_speech {
#   tag: NOUN
#   number: SINGULAR
# }
# dependency_edge {
#   head_token_index: 77
#   label: ROOT
# }
# lemma: "red"
# , text {
#   content: ","
#   begin_offset: -1
# }
# part_of_speech {
#   tag: PUNCT
# }
# dependency_edge {
#   head_token_index: 77
#   label: P
# }
# lemma: ","
# , text {
#   content: "one"
#   begin_offset: -1
# }
# part_of_speech {
#   tag: NUM
# }
# dependency_edge {
#   head_token_index: 80
#   label: NUM
# }
# lemma: "one"
# , text {
#   content: "yellow"
#   begin_offset: -1
# }
# part_of_speech {
#   tag: NOUN
#   number: SINGULAR
# }
# dependency_edge {
#   head_token_index: 77
#   label: APPOS
# }
# lemma: "yellow"
# , text {
#   content: ","
#   begin_offset: -1
# }
# part_of_speech {
#   tag: PUNCT
# }
# dependency_edge {
#   head_token_index: 77
#   label: P
# }
# lemma: ","
# , text {
#   content: "and"
#   begin_offset: -1
# }
# part_of_speech {
#   tag: CONJ
# }
# dependency_edge {
#   head_token_index: 77
#   label: CC
# }
# lemma: "and"
# , text {
#   content: "leave"
#   begin_offset: -1
# }
# part_of_speech {
#   tag: VERB
#   mood: INDICATIVE
# }
# dependency_edge {
#   head_token_index: 77
#   label: CONJ
# }
# lemma: "leave"
# , text {
#   content: "one"
#   begin_offset: -1
# }
# part_of_speech {
#   tag: NUM
# }
# dependency_edge {
#   head_token_index: 85
#   label: NUM
# }
# lemma: "one"
# , text {
#   content: "plain"
#   begin_offset: -1
# }
# part_of_speech {
#   tag: NOUN
#   number: SINGULAR
# }
# dependency_edge {
#   head_token_index: 83
#   label: DOBJ
# }
# lemma: "plain"
# , text {
#   content: "."
#   begin_offset: -1
# }
# part_of_speech {
#   tag: PUNCT
# }
# dependency_edge {
#   head_token_index: 77
#   label: P
# }
# lemma: "."
# , text {
#   content: "Toss"
#   begin_offset: -1
# }
# part_of_speech {
#   tag: VERB
# }
# dependency_edge {
#   head_token_index: 87
#   label: ROOT
# }
# lemma: "Toss"
# , text {
#   content: "the"
#   begin_offset: -1
# }
# part_of_speech {
#   tag: DET
# }
# dependency_edge {
#   head_token_index: 90
#   label: DET
# }
# lemma: "the"
# , text {
#   content: "colored"
#   begin_offset: -1
# }
# part_of_speech {
#   tag: ADJ
# }
# dependency_edge {
#   head_token_index: 90
#   label: AMOD
# }
# lemma: "colored"
# , text {
#   content: "coconut"
#   begin_offset: -1
# }
# part_of_speech {
#   tag: NOUN
#   number: SINGULAR
# }
# dependency_edge {
#   head_token_index: 87
#   label: DOBJ
# }
# lemma: "coconut"
# , text {
#   content: "together"
#   begin_offset: -1
# }
# part_of_speech {
#   tag: ADV
# }
# dependency_edge {
#   head_token_index: 87
#   label: ADVMOD
# }
# lemma: "together"
# , text {
#   content: "with"
#   begin_offset: -1
# }
# part_of_speech {
#   tag: ADP
# }
# dependency_edge {
#   head_token_index: 87
#   label: PREP
# }
# lemma: "with"
# , text {
#   content: "the"
#   begin_offset: -1
# }
# part_of_speech {
#   tag: DET
# }
# dependency_edge {
#   head_token_index: 94
#   label: DET
# }
# lemma: "the"
# , text {
#   content: "plain"
#   begin_offset: -1
# }
# part_of_speech {
#   tag: NOUN
#   number: SINGULAR
# }
# dependency_edge {
#   head_token_index: 92
#   label: POBJ
# }
# lemma: "plain"
# , text {
#   content: ".."
#   begin_offset: -1
# }
# part_of_speech {
#   tag: PUNCT
# }
# dependency_edge {
#   head_token_index: 87
#   label: P
# }
# lemma: ".."
# , text {
#   content: "Roll"
#   begin_offset: -1
# }
# part_of_speech {
#   tag: VERB
#   number: SINGULAR
# }
# dependency_edge {
#   head_token_index: 87
#   label: PARATAXIS
# }
# lemma: "Roll"
# , text {
#   content: "cookie"
#   begin_offset: -1
# }
# part_of_speech {
#   tag: NOUN
#   number: SINGULAR
# }
# dependency_edge {
#   head_token_index: 98
#   label: NN
# }
# lemma: "cookie"
# , text {
#   content: "dough"
#   begin_offset: -1
# }
# part_of_speech {
#   tag: NOUN
#   number: SINGULAR
# }
# dependency_edge {
#   head_token_index: 96
#   label: DOBJ
# }
# lemma: "dough"
# , text {
#   content: "into"
#   begin_offset: -1
# }
# part_of_speech {
#   tag: ADP
# }
# dependency_edge {
#   head_token_index: 96
#   label: PREP
# }
# lemma: "into"
# , text {
#   content: "walnut"
#   begin_offset: -1
# }
# part_of_speech {
#   tag: NOUN
#   number: SINGULAR
# }
# dependency_edge {
#   head_token_index: 102
#   label: NPADVMOD
# }
# lemma: "walnut"
# , text {
#   content: "-"
#   begin_offset: -1
# }
# part_of_speech {
#   tag: PUNCT
# }
# dependency_edge {
#   head_token_index: 102
#   label: P
# }
# lemma: "-"
# , text {
#   content: "sized"
#   begin_offset: -1
# }
# part_of_speech {
#   tag: ADJ
#   number: SINGULAR
# }
# dependency_edge {
#   head_token_index: 103
#   label: AMOD
# }
# lemma: "sized"
# , text {
#   content: "balls"
#   begin_offset: -1
# }
# part_of_speech {
#   tag: NOUN
#   number: PLURAL
# }
# dependency_edge {
#   head_token_index: 99
#   label: POBJ
# }
# lemma: "ball"
# , text {
#   content: ","
#   begin_offset: -1
# }
# part_of_speech {
#   tag: PUNCT
# }
# dependency_edge {
#   head_token_index: 96
#   label: P
# }
# lemma: ","
# , text {
#   content: "then"
#   begin_offset: -1
# }
# part_of_speech {
#   tag: ADV
# }
# dependency_edge {
#   head_token_index: 96
#   label: ADVMOD
# }
# lemma: "then"
# , text {
#   content: "roll"
#   begin_offset: -1
# }
# part_of_speech {
#   tag: VERB
# }
# dependency_edge {
#   head_token_index: 96
#   label: DEP
# }
# lemma: "roll"
# , text {
#   content: "the"
#   begin_offset: -1
# }
# part_of_speech {
#   tag: DET
# }
# dependency_edge {
#   head_token_index: 108
#   label: DET
# }
# lemma: "the"
# , text {
#   content: "balls"
#   begin_offset: -1
# }
# part_of_speech {
#   tag: NOUN
#   number: PLURAL
# }
# dependency_edge {
#   head_token_index: 106
#   label: DOBJ
# }
# lemma: "ball"
# , text {
#   content: "in"
#   begin_offset: -1
# }
# part_of_speech {
#   tag: ADP
# }
# dependency_edge {
#   head_token_index: 106
#   label: PREP
# }
# lemma: "in"
# , text {
#   content: "the"
#   begin_offset: -1
# }
# part_of_speech {
#   tag: DET
# }
# dependency_edge {
#   head_token_index: 112
#   label: DET
# }
# lemma: "the"
# , text {
#   content: "coconut"
#   begin_offset: -1
# }
# part_of_speech {
#   tag: NOUN
#   number: SINGULAR
# }
# dependency_edge {
#   head_token_index: 112
#   label: NN
# }
# lemma: "coconut"
# , text {
#   content: "mixture"
#   begin_offset: -1
# }
# part_of_speech {
#   tag: NOUN
#   number: SINGULAR
# }
# dependency_edge {
#   head_token_index: 109
#   label: POBJ
# }
# lemma: "mixture"
# , text {
#   content: "."
#   begin_offset: -1
# }
# part_of_speech {
#   tag: PUNCT
# }
# dependency_edge {
#   head_token_index: 87
#   label: P
# }
# lemma: "."
# , text {
#   content: "Place"
#   begin_offset: -1
# }
# part_of_speech {
#   tag: VERB
# }
# dependency_edge {
#   head_token_index: 114
#   label: ROOT
# }
# lemma: "Place"
# , text {
#   content: "them"
#   begin_offset: -1
# }
# part_of_speech {
#   tag: PRON
#   case: ACCUSATIVE
#   number: PLURAL
#   person: THIRD
# }
# dependency_edge {
#   head_token_index: 114
#   label: IOBJ
# }
# lemma: "them"
# , text {
#   content: "2"
#   begin_offset: -1
# }
# part_of_speech {
#   tag: NUM
# }
# dependency_edge {
#   head_token_index: 117
#   label: NUM
# }
# lemma: "2"
# , text {
#   content: "inches"
#   begin_offset: -1
# }
# part_of_speech {
#   tag: NOUN
#   number: PLURAL
# }
# dependency_edge {
#   head_token_index: 114
#   label: DOBJ
# }
# lemma: "inch"
# , text {
#   content: "apart"
#   begin_offset: -1
# }
# part_of_speech {
#   tag: ADV
# }
# dependency_edge {
#   head_token_index: 114
#   label: ADVMOD
# }
# lemma: "apart"
# , text {
#   content: "onto"
#   begin_offset: -1
# }
# part_of_speech {
#   tag: ADP
# }
# dependency_edge {
#   head_token_index: 114
#   label: PREP
# }
# lemma: "onto"
# , text {
#   content: "the"
#   begin_offset: -1
# }
# part_of_speech {
#   tag: DET
# }
# dependency_edge {
#   head_token_index: 123
#   label: DET
# }
# lemma: "the"
# , text {
#   content: "prepared"
#   begin_offset: -1
# }
# part_of_speech {
#   tag: ADJ
#   tense: PAST
# }
# dependency_edge {
#   head_token_index: 123
#   label: AMOD
# }
# lemma: "prepared"
# , text {
#   content: "cookie"
#   begin_offset: -1
# }
# part_of_speech {
#   tag: NOUN
#   number: SINGULAR
# }
# dependency_edge {
#   head_token_index: 123
#   label: NN
# }
# lemma: "cookie"
# , text {
#   content: "sheet"
#   begin_offset: -1
# }
# part_of_speech {
#   tag: NOUN
#   number: SINGULAR
# }
# dependency_edge {
#   head_token_index: 119
#   label: POBJ
# }
# lemma: "sheet"
# , text {
#   content: "."
#   begin_offset: -1
# }
# part_of_speech {
#   tag: PUNCT
# }
# dependency_edge {
#   head_token_index: 114
#   label: P
# }
# lemma: "."
# , text {
#   content: "Press"
#   begin_offset: -1
# }
# part_of_speech {
#   tag: NOUN
#   number: SINGULAR
# }
# dependency_edge {
#   head_token_index: 127
#   label: NN
# }
# lemma: "Press"
# , text {
#   content: "1"
#   begin_offset: -1
# }
# part_of_speech {
#   tag: NUM
# }
# dependency_edge {
#   head_token_index: 125
#   label: NUM
# }
# lemma: "1"
# , text {
#   content: "candy"
#   begin_offset: -1
# }
# part_of_speech {
#   tag: NOUN
#   number: SINGULAR
# }
# dependency_edge {
#   head_token_index: 127
#   label: ROOT
# }
# lemma: "candy"
# , text {
#   content: "into"
#   begin_offset: -1
# }
# part_of_speech {
#   tag: ADP
# }
# dependency_edge {
#   head_token_index: 127
#   label: PREP
# }
# lemma: "into"
# , text {
#   content: "the"
#   begin_offset: -1
# }
# part_of_speech {
#   tag: DET
# }
# dependency_edge {
#   head_token_index: 130
#   label: DET
# }
# lemma: "the"
# , text {
#   content: "center"
#   begin_offset: -1
# }
# part_of_speech {
#   tag: NOUN
#   number: SINGULAR
# }
# dependency_edge {
#   head_token_index: 128
#   label: POBJ
# }
# lemma: "center"
# , text {
#   content: "of"
#   begin_offset: -1
# }
# part_of_speech {
#   tag: ADP
# }
# dependency_edge {
#   head_token_index: 130
#   label: PREP
# }
# lemma: "of"
# , text {
#   content: "each"
#   begin_offset: -1
# }
# part_of_speech {
#   tag: DET
# }
# dependency_edge {
#   head_token_index: 133
#   label: DET
# }
# lemma: "each"
# , text {
#   content: "cookie"
#   begin_offset: -1
# }
# part_of_speech {
#   tag: NOUN
#   number: SINGULAR
# }
# dependency_edge {
#   head_token_index: 131
#   label: POBJ
# }
# lemma: "cookie"
# , text {
#   content: ".."
#   begin_offset: -1
# }
# part_of_speech {
#   tag: PUNCT
# }
# dependency_edge {
#   head_token_index: 127
#   label: P
# }
# lemma: ".."
# , text {
#   content: "Bake"
#   begin_offset: -1
# }
# part_of_speech {
#   tag: VERB
#   number: SINGULAR
# }
# dependency_edge {
#   head_token_index: 127
#   label: DEP
# }
# lemma: "Bake"
# , text {
#   content: "for"
#   begin_offset: -1
# }
# part_of_speech {
#   tag: ADP
# }
# dependency_edge {
#   head_token_index: 135
#   label: PREP
# }
# lemma: "for"
# , text {
#   content: "12"
#   begin_offset: -1
# }
# part_of_speech {
#   tag: NUM
# }
# dependency_edge {
#   head_token_index: 138
#   label: NUM
# }
# lemma: "12"
# , text {
#   content: "minutes"
#   begin_offset: -1
# }
# part_of_speech {
#   tag: NOUN
#   number: PLURAL
# }
# dependency_edge {
#   head_token_index: 136
#   label: POBJ
# }
# lemma: "minute"
# , text {
#   content: "in"
#   begin_offset: -1
# }
# part_of_speech {
#   tag: ADP
# }
# dependency_edge {
#   head_token_index: 135
#   label: PREP
# }
# lemma: "in"
# , text {
#   content: "the"
#   begin_offset: -1
# }
# part_of_speech {
#   tag: DET
# }
# dependency_edge {
#   head_token_index: 142
#   label: DET
# }
# lemma: "the"
# , text {
#   content: "preheated"
#   begin_offset: -1
# }
# part_of_speech {
#   tag: ADJ
#   number: SINGULAR
# }
# dependency_edge {
#   head_token_index: 142
#   label: AMOD
# }
# lemma: "preheated"
# , text {
#   content: "oven"
#   begin_offset: -1
# }
# part_of_speech {
#   tag: NOUN
#   number: SINGULAR
# }
# dependency_edge {
#   head_token_index: 139
#   label: POBJ
# }
# lemma: "oven"
# , text {
#   content: ","
#   begin_offset: -1
# }
# part_of_speech {
#   tag: PUNCT
# }
# dependency_edge {
#   head_token_index: 135
#   label: P
# }
# lemma: ","
# , text {
#   content: "then"
#   begin_offset: -1
# }
# part_of_speech {
#   tag: ADV
# }
# dependency_edge {
#   head_token_index: 135
#   label: ADVMOD
# }
# lemma: "then"
# , text {
#   content: "remove"
#   begin_offset: -1
# }
# part_of_speech {
#   tag: VERB
# }
# dependency_edge {
#   head_token_index: 135
#   label: DEP
# }
# lemma: "remove"
# , text {
#   content: "from"
#   begin_offset: -1
# }
# part_of_speech {
#   tag: ADP
# }
# dependency_edge {
#   head_token_index: 145
#   label: PREP
# }
# lemma: "from"
# , text {
#   content: "the"
#   begin_offset: -1
# }
# part_of_speech {
#   tag: DET
# }
# dependency_edge {
#   head_token_index: 148
#   label: DET
# }
# lemma: "the"
# , text {
#   content: "oven"
#   begin_offset: -1
# }
# part_of_speech {
#   tag: NOUN
#   number: SINGULAR
# }
# dependency_edge {
#   head_token_index: 146
#   label: POBJ
# }
# lemma: "oven"
# , text {
#   content: "and"
#   begin_offset: -1
# }
# part_of_speech {
#   tag: CONJ
# }
# dependency_edge {
#   head_token_index: 135
#   label: CC
# }
# lemma: "and"
# , text {
#   content: "press"
#   begin_offset: -1
# }
# part_of_speech {
#   tag: NOUN
#   number: SINGULAR
# }
# dependency_edge {
#   head_token_index: 135
#   label: CONJ
# }
# lemma: "press"
# , text {
#   content: "2"
#   begin_offset: -1
# }
# part_of_speech {
#   tag: NUM
# }
# dependency_edge {
#   head_token_index: 150
#   label: NUM
# }
# lemma: "2"
# , text {
#   content: "more"
#   begin_offset: -1
# }
# part_of_speech {
#   tag: ADJ
# }
# dependency_edge {
#   head_token_index: 153
#   label: AMOD
# }
# lemma: "more"
# , text {
#   content: "candies"
#   begin_offset: -1
# }
# part_of_speech {
#   tag: NOUN
#   number: PLURAL
# }
# dependency_edge {
#   head_token_index: 135
#   label: DOBJ
# }
# lemma: "candy"
# , text {
#   content: "into"
#   begin_offset: -1
# }
# part_of_speech {
#   tag: ADP
# }
# dependency_edge {
#   head_token_index: 135
#   label: PREP
# }
# lemma: "into"
# , text {
#   content: "the"
#   begin_offset: -1
# }
# part_of_speech {
#   tag: DET
# }
# dependency_edge {
#   head_token_index: 156
#   label: DET
# }
# lemma: "the"
# , text {
#   content: "center"
#   begin_offset: -1
# }
# part_of_speech {
#   tag: NOUN
#   number: SINGULAR
# }
# dependency_edge {
#   head_token_index: 154
#   label: POBJ
# }
# lemma: "center"
# , text {
#   content: "of"
#   begin_offset: -1
# }
# part_of_speech {
#   tag: ADP
# }
# dependency_edge {
#   head_token_index: 156
#   label: PREP
# }
# lemma: "of"
# , text {
#   content: "each"
#   begin_offset: -1
# }
# part_of_speech {
#   tag: DET
# }
# dependency_edge {
#   head_token_index: 159
#   label: DET
# }
# lemma: "each"
# , text {
#   content: "cookie"
#   begin_offset: -1
# }
# part_of_speech {
#   tag: NOUN
#   number: SINGULAR
# }
# dependency_edge {
#   head_token_index: 157
#   label: POBJ
# }
# lemma: "cookie"
# , text {
#   content: "."
#   begin_offset: -1
# }
# part_of_speech {
#   tag: PUNCT
# }
# dependency_edge {
#   head_token_index: 127
#   label: P
# }
# lemma: "."
# , text {
#   content: "Return"
#   begin_offset: -1
# }
# part_of_speech {
#   tag: VERB
#   number: SINGULAR
# }
# dependency_edge {
#   head_token_index: 161
#   label: ROOT
# }
# lemma: "Return"
# , text {
#   content: "to"
#   begin_offset: -1
# }
# part_of_speech {
#   tag: ADP
# }
# dependency_edge {
#   head_token_index: 161
#   label: PREP
# }
# lemma: "to"
# , text {
#   content: "the"
#   begin_offset: -1
# }
# part_of_speech {
#   tag: DET
# }
# dependency_edge {
#   head_token_index: 164
#   label: DET
# }
# lemma: "the"
# , text {
#   content: "oven"
#   begin_offset: -1
# }
# part_of_speech {
#   tag: NOUN
#   number: SINGULAR
# }
# dependency_edge {
#   head_token_index: 162
#   label: POBJ
# }
# lemma: "oven"
# , text {
#   content: "to"
#   begin_offset: -1
# }
# part_of_speech {
#   tag: PRT
# }
# dependency_edge {
#   head_token_index: 166
#   label: AUX
# }
# lemma: "to"
# , text {
#   content: "continue"
#   begin_offset: -1
# }
# part_of_speech {
#   tag: VERB
# }
# dependency_edge {
#   head_token_index: 161
#   label: XCOMP
# }
# lemma: "continue"
# , text {
#   content: "baking"
#   begin_offset: -1
# }
# part_of_speech {
#   tag: VERB
#   number: SINGULAR
# }
# dependency_edge {
#   head_token_index: 166
#   label: XCOMP
# }
# lemma: "bake"
# , text {
#   content: "for"
#   begin_offset: -1
# }
# part_of_speech {
#   tag: ADP
# }
# dependency_edge {
#   head_token_index: 167
#   label: PREP
# }
# lemma: "for"
# , text {
#   content: "another"
#   begin_offset: -1
# }
# part_of_speech {
#   tag: DET
# }
# dependency_edge {
#   head_token_index: 173
#   label: DET
# }
# lemma: "another"
# , text {
#   content: "4"
#   begin_offset: -1
# }
# part_of_speech {
#   tag: NUM
# }
# dependency_edge {
#   head_token_index: 172
#   label: NUMBER
# }
# lemma: "4"
# , text {
#   content: "to"
#   begin_offset: -1
# }
# part_of_speech {
#   tag: ADP
# }
# dependency_edge {
#   head_token_index: 172
#   label: QUANTMOD
# }
# lemma: "to"
# , text {
#   content: "5"
#   begin_offset: -1
# }
# part_of_speech {
#   tag: NUM
# }
# dependency_edge {
#   head_token_index: 173
#   label: NUM
# }
# lemma: "5"
# , text {
#   content: "minutes"
#   begin_offset: -1
# }
# part_of_speech {
#   tag: NOUN
#   number: PLURAL
# }
# dependency_edge {
#   head_token_index: 168
#   label: POBJ
# }
# lemma: "minute"
# , text {
#   content: ","
#   begin_offset: -1
# }
# part_of_speech {
#   tag: PUNCT
# }
# dependency_edge {
#   head_token_index: 161
#   label: P
# }
# lemma: ","
# , text {
#   content: "until"
#   begin_offset: -1
# }
# part_of_speech {
#   tag: ADP
# }
# dependency_edge {
#   head_token_index: 161
#   label: PREP
# }
# lemma: "until"
# , text {
#   content: "golden"
#   begin_offset: -1
# }
# part_of_speech {
#   tag: ADJ
# }
# dependency_edge {
#   head_token_index: 177
#   label: AMOD
# }
# lemma: "golden"
# , text {
#   content: "brown"
#   begin_offset: -1
# }
# part_of_speech {
#   tag: NOUN
#   number: SINGULAR
# }
# dependency_edge {
#   head_token_index: 175
#   label: POBJ
# }
# lemma: "brown"
# , text {
#   content: "."
#   begin_offset: -1
# }
# part_of_speech {
#   tag: PUNCT
# }
# dependency_edge {
#   head_token_index: 161
#   label: P
# }
# lemma: "."
# , text {
#   content: "Cool"
#   begin_offset: -1
# }
# part_of_speech {
#   tag: ADJ
# }
# dependency_edge {
#   head_token_index: 180
#   label: AMOD
# }
# lemma: "Cool"
# , text {
#   content: "cookies"
#   begin_offset: -1
# }
# part_of_speech {
#   tag: NOUN
#   number: PLURAL
# }
# dependency_edge {
#   head_token_index: 180
#   label: ROOT
# }
# lemma: "cookie"
# , text {
#   content: "on"
#   begin_offset: -1
# }
# part_of_speech {
#   tag: ADP
# }
# dependency_edge {
#   head_token_index: 180
#   label: PREP
# }
# lemma: "on"
# , text {
#   content: "the"
#   begin_offset: -1
# }
# part_of_speech {
#   tag: DET
# }
# dependency_edge {
#   head_token_index: 184
#   label: DET
# }
# lemma: "the"
# , text {
#   content: "baking"
#   begin_offset: -1
# }
# part_of_speech {
#   tag: NOUN
#   number: SINGULAR
# }
# dependency_edge {
#   head_token_index: 184
#   label: NN
# }
# lemma: "baking"
# , text {
#   content: "sheet"
#   begin_offset: -1
# }
# part_of_speech {
#   tag: NOUN
#   number: SINGULAR
# }
# dependency_edge {
#   head_token_index: 181
#   label: POBJ
# }
# lemma: "sheet"
# , text {
#   content: "for"
#   begin_offset: -1
# }
# part_of_speech {
#   tag: ADP
# }
# dependency_edge {
#   head_token_index: 180
#   label: PREP
# }
# lemma: "for"
# , text {
#   content: "a"
#   begin_offset: -1
# }
# part_of_speech {
#   tag: DET
# }
# dependency_edge {
#   head_token_index: 188
#   label: DET
# }
# lemma: "a"
# , text {
#   content: "few"
#   begin_offset: -1
# }
# part_of_speech {
#   tag: ADJ
# }
# dependency_edge {
#   head_token_index: 188
#   label: AMOD
# }
# lemma: "few"
# , text {
#   content: "minutes"
#   begin_offset: -1
# }
# part_of_speech {
#   tag: NOUN
#   number: PLURAL
# }
# dependency_edge {
#   head_token_index: 185
#   label: POBJ
# }
# lemma: "minute"
# , text {
#   content: "before"
#   begin_offset: -1
# }
# part_of_speech {
#   tag: ADP
# }
# dependency_edge {
#   head_token_index: 180
#   label: PREP
# }
# lemma: "before"
# , text {
#   content: "removing"
#   begin_offset: -1
# }
# part_of_speech {
#   tag: VERB
# }
# dependency_edge {
#   head_token_index: 189
#   label: PCOMP
# }
# lemma: "remove"
# , text {
#   content: "to"
#   begin_offset: -1
# }
# part_of_speech {
#   tag: ADP
# }
# dependency_edge {
#   head_token_index: 190
#   label: PREP
# }
# lemma: "to"
# , text {
#   content: "a"
#   begin_offset: -1
# }
# part_of_speech {
#   tag: DET
# }
# dependency_edge {
#   head_token_index: 194
#   label: DET
# }
# lemma: "a"
# , text {
#   content: "wire"
#   begin_offset: -1
# }
# part_of_speech {
#   tag: NOUN
#   number: SINGULAR
# }
# dependency_edge {
#   head_token_index: 194
#   label: NN
# }
# lemma: "wire"
# , text {
#   content: "rack"
#   begin_offset: -1
# }
# part_of_speech {
#   tag: NOUN
#   number: SINGULAR
# }
# dependency_edge {
#   head_token_index: 191
#   label: POBJ
# }
# lemma: "rack"
# , text {
#   content: "to"
#   begin_offset: -1
# }
# part_of_speech {
#   tag: PRT
# }
# dependency_edge {
#   head_token_index: 196
#   label: AUX
# }
# lemma: "to"
# , text {
#   content: "cool"
#   begin_offset: -1
# }
# part_of_speech {
#   tag: VERB
# }
# dependency_edge {
#   head_token_index: 190
#   label: XCOMP
# }
# lemma: "cool"
# , text {
#   content: "completely"
#   begin_offset: -1
# }
# part_of_speech {
#   tag: ADV
# }
# dependency_edge {
#   head_token_index: 196
#   label: ADVMOD
# }
# lemma: "completely"
# , text {
#   content: "."
#   begin_offset: -1
# }
# part_of_speech {
#   tag: PUNCT
# }
# dependency_edge {
#   head_token_index: 180
#   label: P
# }
# lemma: "."
# ]

# %%
# Iterate through df extract cleaner Ingredients into a dictionary, and save on disk.
cleanedIngredientsDict=defaultdict()
cleanedIngredientsDict=pd.read_pickle('cleanerIngredients.pkl')  
insDict=parsing_util.Instructions()
added=0

for idx, row in ProgressBar(df.iterrows(), desc="Processing recipes"):
    url=row["url"]
    if url in cleanedIngredientsDict: continue
    # print 'loading ' + row["url"]   
    parsedInstructions = insDict.parse(url, row["instructionSteps"])
    cleanIng = parsing_util.get_ingredients(parsedInstructions, row["ingredients"], ingredientsDict,0)
    cleanedIngredientsDict[url] = cleanIng
    added += 1
    if added > 10000:
        with open('cleanerIngredients.pkl', 'wb') as f:
            pickle.dump(cleanedIngredientsDict, f) 
        added = 0
    
with open('cleanerIngredients.pkl', 'wb') as f:
    pickle.dump(cleanedIngredientsDict, f)
insDict.close()    
#ingredientsDict=pd.read_pickle('parsedInstruction.pkl')    
#for key,value in ingredientsDict.iteritems():
#    print key
# Out:
# Processing recipes: 48417it [19:13, 41.96it/s]

# %%
CleanIngredientsDict=pd.read_pickle('cleanerIngredients.pkl')  
print len(CleanIngredientsDict)
#for key,value in ingredientsDict.iteritems():
#    print key
#with open('parsedIngredients.pkl', 'wb') as f:
#    pickle.dump(IngredientsDict, f)
for key,item in sorted(CleanIngredientsDict.items(), reverse=False, key=operator.itemgetter(1))[:5]:
    print item
print
print CleanIngredientsDict[u'http://allrecipes.com/recipe/33385/best-spanish-rice/']
# Out:
# 48417
# set([u'onion', u'ginger paste', u'soy sauce', u'rice wine vinegar', u'lemon juice', u'black pepper', u'garlic', u'yogurt', u'sugar', u'ketchup'])
# set([u'olive oil', u'pepper', u'kosher salt', u'celery', u'chicken', u'pink salt'])
# set([u'ginger ale', u'pineapple juice', u'white grape juice'])
# set([u'whiskey', u'lime soda', u'amaretto'])
# set([u'red bell pepper', u'tea', 'almond', u'sesame seed', u'water', u'cabbage', u'rice', u'salt', u'edamame'])
#
# set([u'rice', u'chicken broth', u'onion', u'oil', u'salsa'])

# %%
# Count ingredients. prepare a clean list 
UniqueIngredientsDict=defaultdict(int)
cleanedIngredientsDict=pd.read_pickle('cleanerIngredients.pkl')  
#ingredientsDict=pd.read_pickle('unique_ingredients.pkl')

for url,ingredients in cleanedIngredientsDict.items():
    for ingredient in ingredients:
        UniqueIngredientsDict[ingredient] += 1
    #print ingredient

for url,ingredients in sorted(cleanedIngredientsDict.items(), reverse=False, key=operator.itemgetter(1))[:10]:
    print url,ingredients
# Out:
# http://allrecipes.com/recipe/237328/asian-inspired-ginger-dressing/ set([u'onion', u'ginger paste', u'soy sauce', u'rice wine vinegar', u'lemon juice', u'black pepper', u'garlic', u'yogurt', u'sugar', u'ketchup'])
# http://allrecipes.com/recipe/255246/abbeys-best-roast-chicken/ set([u'olive oil', u'pepper', u'kosher salt', u'celery', u'chicken', u'pink salt'])
# http://allrecipes.com/recipe/32333/mock-champagne/ set([u'ginger ale', u'pineapple juice', u'white grape juice'])
# http://allrecipes.com/recipe/59314/winston-punch/ set([u'whiskey', u'lime soda', u'amaretto'])
# http://allrecipes.com/recipe/242512/asian-cabbage-and-tea-rice/ set([u'red bell pepper', u'tea', 'almond', u'sesame seed', u'water', u'cabbage', u'rice', u'salt', u'edamame'])
# http://allrecipes.com/recipe/218298/turkey-filled-omelette/ set([u'olive oil', u'butter', 'red pepper flake', u'shiitake mushroom', u'white pepper', u'shallot', u'vermouth', u'sage', u'turkey', u'salt', u'egg', u'creme fraiche'])
# http://allrecipes.com/recipe/21855/poke-cake-iii/ set([u'water', u'topping', u'cake mix', u'cherry pie filling', 'fruit flavored mix'])
# http://allrecipes.com/recipe/256486/bacon-wrapped-asparagus-on-toast/ set([u'butter', u'red pepper flake', u'bacon', u'asparagu', u'garlic salt', u'mozzarella cheese', u'bread'])
# http://allrecipes.com/recipe/257730/vegan-muesli/ set([u'maple syrup', u'coconut milk', u'apple', 'strawberry', u'lemon juice', 'oat', 'chia seed', 'blueberry'])
# http://allrecipes.com/recipe/140412/jiddos-fatayer-sabanegh-spinach-triangles/ set([u'olive oil', u'onion', u'spinach', u'flour', u'mint', 'warm water degrees f', u'sugar', u'garlic salt', u'lemon juice', u'garlic', u'basil', u'yeast', u'salt'])

# %%
print len(UniqueIngredientsDict)
print UniqueIngredientsDict["roma tomato"]
# Out:
# 10056
# 53

# %% [markdown]
# ## Debugging code below

# %%
# For debugging
insDict=parsing_util.Instructions()
reload(parsing_util)
url=u'http://allrecipes.com/recipe/33385/best-spanish-rice/'
Instructions=str(df2.loc[url,'instructionSteps'])
ingredients=df2.loc[url,'ingredients']

#Instructions="[u'Whisk the paprika, garlic, Italian seasoning, lemon juice, olive oil, pepper, basil, and brown sugar together in a bowl until thoroughly blended. Stir in the shrimp, and toss to evenly coat with the marinade. Cover and refrigerate at least 2 hours, turning once.', u'Preheat an outdoor grill for medium-high heat. Lightly oil grill grate, and place about 4 inches from heat source.', u'Remove shrimp from marinade, drain excess, and discard marinade.', u'Place shrimp on preheated grill and cook, turning once, until opaque in the center, 5 to 6 minutes. Serve immediately.']"
#ingredients=[u'2 teaspoons ground paprika', u'2 tablespoons fresh minced garlic', u'2 teaspoons Italian seasoning blend', u'2 tablespoons fresh lemon juice', u'1/4 cup olive oil', u'1/2 teaspoon ground black pepper', u'2 teaspoons dried basil leaves', u'2 tablespoons brown sugar, packed', u'2 pounds large shrimp (21-25 per pound), peeled and deveined', u'Add all ingredients to list', u'Add all ingredients to list']
parsedInstructions = insDict.parse(url, Instructions)

print Instructions
print ingredients
print parsing_util.get_ingredients(parsedInstructions, ingredients, ingredientsDict, 10)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-5151dffc0371> in <module>()
#       1 # For debugging
# ----> 2 insDict=parsing_util.Instructions()
#       3 reload(parsing_util)
#       4 url=u'http://allrecipes.com/recipe/33385/best-spanish-rice/'
#       5 Instructions=str(df2.loc[url,'instructionSteps'])
#
# NameError: name 'parsing_util' is not defined

# %%
for idx, row in df.sample(3).iterrows():
    parsedInstructions = insDict.parse(row["url"], row["instructionSteps"])
    cleanIng = parsing_util.get_ingredients(parsedInstructions, row["ingredients"], ingredientsDict,2)
    print "url='"+row["url"]+"'"
    print 'Instructions="'+str(row["instructionSteps"])+'"'
    print 'ingredients='+str(row["ingredients"])
    # print cleanIng
    print
insDict.close()
# Out:
# ['lima bean', 'red pepper flake']
# url='http://allrecipes.com/recipe/237543/firehouse-butter-beans-and-sausage/'
# Instructions="[u'Place lima beans in a large pot with enough water to cover by 2 inches; bring to a boil. Remove pot from heat and let stand for 2 hours. Drain and rinse beans under cold water.', u'Transfer beans back to large pot and pour in enough water to cover; add sausage and red pepper flakes. Bring water to a boil, decrease heat, and simmer, adding water as needed to keep beans from sticking to the bottom, until beans are tender and liquid has thickened, 1 to 2 hours.']"
# ingredients=[u'3 (16 ounce) packages dried lima beans', u'water to cover', u'2 1/2 pounds fully-cooked pork sausage, cut into 2-inch pieces', u'2 tablespoons red pepper flakes', u'Add all ingredients to list', u'Add all ingredients to list']
#
# ['lemonlime flavored carbonated beverage']
# url='http://allrecipes.com/recipe/22278/easy-fruit-cobbler-cake/'
# Instructions="[u'Preheat oven to 375 degrees F (190 degrees C). Grease a 9x13 inch pan.', u'Spread pie filling over the bottom of the prepared pan, then sprinkle evenly with the cake mix.  Pour lemon-lime soda over the top.  Bake in preheated oven for 45 minutes.']"
# ingredients=[u'1 (21 ounce) can blueberry pie filling', u'1 (18.25 ounce) package yellow cake mix', u'1 (12 fluid ounce) can or bottle lemon-lime flavored carbonated beverage', u'Add all ingredients to list', u'Add all ingredients to list']
#
# ['stevia powder', 'colored sprinkle']
# url='http://allrecipes.com/recipe/257195/gluten-free-easter-egg-cookies/'
# Instructions="[u'Preheat oven to 350 degrees F (175 degrees C).', u'Combine cassava flour, potato starch, and stevia powder in a bowl; add coconut milk, coconut oil, egg yolks, orange liqueur, and honey and knead until dough is well mixed.', u'Roll dough on a work surface using a rolling pin until 1/4-inch thick. Cut egg-shaped cookies using an egg-shaped cookie cutter. Place egg-shaped cookies on a baking sheet. Spread jam over each cookie and top with sprinkles.', u'Bake in the preheated oven until edges start to become lightly browned, about 25 minutes. Cool completely.']"
# ingredients=[u'1 cup cassava flour (such as Amafil\xae)', u'1 cup potato starch', u'1 pinch stevia powder', u'6 tablespoons coconut milk', u'5 tablespoons coconut oil', u'4 egg yolks', u'2 tablespoons brandy-based orange liqueur (such as Grand Marnier\xae)', u'1 tablespoon honey', u'2 tablespoons peach jam', u'1 tablespoon colored sprinkles', u'Add all ingredients to list', u'Add all ingredients to list']

# %%
# For debugging: find fro which recipe "yellow" came from 
for url,ingredients in cleanedIngredientsDict.items():
    if 'yellow' in ingredients:
        print url,ingredients
# Out:
# http://allrecipes.com/recipe/18080/almond-macaroon-nests/ set([u'butter', u'coconut', 'red food coloring', u'flour', u'vanilla', u'yellow', u'sugar', u'baking powder', 'chocolate coated peanut', u'salt', u'cream'])
